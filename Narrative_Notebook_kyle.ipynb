# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Predicting Readmission of Diabetes Patients

# %% [markdown]
# In this project, we see if were are able to predict the readmittance of diabetes patients given data both about the patient and the treatment the patient received.

# %% [markdown]
# The dataset we use is _Diabetes 130-US hospitals for years 1999-2008_, available in the Public Domain through [UCI's Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/diabetes+130-us+hospitals+for+years+1999-2008#) and [Kaggle](https://www.kaggle.com/brandao/diabetes). This dataset was first created for the open access journal article by Strack et al. ["Impact of HbA1c Measurement on Hospital Readmission Rates"](https://www.hindawi.com/journals/bmri/2014/781670), itself a subset of the Health Facts Database curated by the Cerner Corporation. The creation of this 100,000+ record dataset was a query of diabetes diagnoses among 74,000,000 visitation records meeting certain criteria (such as length of stay being 24 hours or greater, or laboratory examinations being performed on the patients).

# %%
# !pip install swifter
# Out:
# Collecting swifter
#   Downloading https://files.pythonhosted.org/packages/1f/22/0a46b4d2a417824d7e883a8bd8e01c3b000bbdeaa7c154891b7cba94cbf7/swifter-0.296-py3-none-any.whl
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from swifter) (7.4.0)
# Requirement already satisfied: pandas>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from swifter) (0.24.2)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from swifter) (5.4.5)
# Collecting dask[complete]>=0.19.0 (from swifter)
#   Downloading https://files.pythonhosted.org/packages/b3/56/ea46d9b2ed53f03072087ba811ee580640e16a787d99373a6b82646974bc/dask-2.8.1-py3-none-any.whl (769kB)
#     100% |████████████████████████████████| 778kB 26.2MB/s ta 0:00:01
# Collecting parso>0.4.0 (from swifter)
#   Downloading https://files.pythonhosted.org/packages/a3/bd/bf4e5bd01d79906e5b945a7af033154da49fd2b0d5b5c705a21330323305/parso-0.5.1-py2.py3-none-any.whl (95kB)
#     100% |████████████████████████████████| 102kB 39.2MB/s a 0:00:01
# Requirement already satisfied: numba in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from swifter) (0.38.0)
# Collecting tqdm>=4.33.0 (from swifter)
#   Downloading https://files.pythonhosted.org/packages/bb/62/6f823501b3bf2bac242bd3c320b592ad1516b3081d82c77c1d813f076856/tqdm-4.39.0-py2.py3-none-any.whl (53kB)
#     100% |████████████████████████████████| 61kB 30.6MB/s ta 0:00:01
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipywidgets>=7.0.0->swifter) (3.4.2)
# Requirement already satisfied: nbformat>=4.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipywidgets>=7.0.0->swifter) (4.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipywidgets>=7.0.0->swifter) (4.3.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipywidgets>=7.0.0->swifter) (4.8.2)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipywidgets>=7.0.0->swifter) (6.4.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.23.0->swifter) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.23.0->swifter) (2018.4)
# Requirement already satisfied: numpy>=1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.23.0->swifter) (1.14.3)
# Requirement already satisfied: bokeh>=1.0.0; extra == "complete" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from dask[complete]>=0.19.0->swifter) (1.0.4)
# Requirement already satisfied: toolz>=0.7.3; extra == "complete" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from dask[complete]>=0.19.0->swifter) (0.9.0)
# Collecting fsspec>=0.6.0; extra == "complete" (from dask[complete]>=0.19.0->swifter)
#   Downloading https://files.pythonhosted.org/packages/04/1e/6108c48f2d4ad9ef1a6bff01fb58245c009f37b2bd0505ec6d0f55cc326d/fsspec-0.6.1-py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 34.7MB/s ta 0:00:01
# Collecting partd>=0.3.10; extra == "complete" (from dask[complete]>=0.19.0->swifter)
#   Downloading https://files.pythonhosted.org/packages/44/e1/68dbe731c9c067655bff1eca5b7d40c20ca4b23fd5ec9f3d17e201a6f36b/partd-1.1.0-py3-none-any.whl
# Requirement already satisfied: PyYaml; extra == "complete" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from dask[complete]>=0.19.0->swifter) (3.12)
# Collecting distributed>=2.0; extra == "complete" (from dask[complete]>=0.19.0->swifter)
#   Downloading https://files.pythonhosted.org/packages/33/da/775df17016a32a1e91e7bf7856cd419d38a6ad0c13449f54bcb03ebdcbc2/distributed-2.8.1-py3-none-any.whl (568kB)
#     100% |████████████████████████████████| 573kB 29.9MB/s ta 0:00:01
# Requirement already satisfied: cloudpickle>=0.2.1; extra == "complete" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from dask[complete]>=0.19.0->swifter) (0.5.3)
# Requirement already satisfied: llvmlite>=0.23.0dev0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from numba->swifter) (0.23.1)
# Requirement already satisfied: notebook>=4.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: ipython_genutils in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (2.6.0)
# Requirement already satisfied: jupyter_core in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.4.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets>=7.0.0->swifter) (1.11.0)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets>=7.0.0->swifter) (4.3.0)
# Requirement already satisfied: jupyter_client in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.2.3)
# Requirement already satisfied: tornado>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.0.2)
# Requirement already satisfied: pickleshare in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.7.4)
# Requirement already satisfied: backcall in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.1.0)
# Requirement already satisfied: pygments in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (2.2.0)
# Requirement already satisfied: jedi>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.12.0)
# Requirement already satisfied: setuptools>=18.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (39.1.0)
# Requirement already satisfied: simplegeneric>0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (4.5.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (1.0.15)
# Requirement already satisfied: Jinja2>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (2.10)
# Requirement already satisfied: packaging>=16.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (17.1)
# Requirement already satisfied: pillow>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (5.2.0)
# Requirement already satisfied: locket in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from partd>=0.3.10; extra == "complete"->dask[complete]>=0.19.0->swifter) (0.2.0)
# Requirement already satisfied: click>=6.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (6.7)
# Requirement already satisfied: zict>=0.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (0.1.3)
# Requirement already satisfied: tblib in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.3.2)
# Requirement already satisfied: msgpack in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (0.6.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.5.10)
# Requirement already satisfied: pyzmq>=17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (17.0.0)
# Requirement already satisfied: terminado>=0.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: Send2Trash in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: nbconvert in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (5.4.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.5.2)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from prompt-toolkit<2.0.0,>=1.0.15->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.1.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from Jinja2>=2.7->bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=16.8->bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (2.2.0)
# Requirement already satisfied: heapdict in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from zict>=0.1.3->distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.0.0)
# Requirement already satisfied: mistune>=0.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (0.8.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (0.2.3)
# Requirement already satisfied: bleach in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (2.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (1.4.2)
# Requirement already satisfied: testpath in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (0.3.1)
# Requirement already satisfied: defusedxml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (1.0.1)
# Requirement already satisfied: webencodings in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->swifter) (0.5.1)
# Installing collected packages: fsspec, partd, distributed, dask, parso, tqdm, swifter
#   Found existing installation: partd 0.3.8
#     Uninstalling partd-0.3.8:
#       Successfully uninstalled partd-0.3.8
#   Found existing installation: distributed 1.21.8
#     Uninstalling distributed-1.21.8:
#       Successfully uninstalled distributed-1.21.8
#   Found existing installation: dask 0.17.5
#     Uninstalling dask-0.17.5:
#       Successfully uninstalled dask-0.17.5
#   Found existing installation: parso 0.2.0
#     Uninstalling parso-0.2.0:
#       Successfully uninstalled parso-0.2.0
# Successfully installed dask-2.8.1 distributed-2.8.1 fsspec-0.6.1 parso-0.5.1 partd-1.1.0 swifter-0.296 tqdm-4.39.0
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import swifter
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
style.use('ggplot')
import operator
import data_prep as d
import functions as f
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, recall_score
from sklearn.metrics import auc, precision_recall_curve
from sklearn.pipeline import Pipeline
from sklearn.utils import resample
# %load_ext autoreload
# %autoreload 2
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# First, we download the features and the target datasets using d.clean(). This function isolates the target variables, removes unnecessary features, creates new features defined by diagnositic and administrative categories, and pre-processes the data for analysis.

# %%
X, y = d.clean()
# Out:
# Upload
# y_clean
# null_value_drop
# reset_indices
# column_drop
# x_clean
# values_lower
# column_lowercase
# categorize_all
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# diagnoses_1_3
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# diagnoses_2_3
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# diagnoses_3_3
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# number_meds
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# num_down
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# num_up
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# X_dummy_variables
# outliers_bin
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=68130, style=ProgressStyle(description_wid…
# outliers_log

# %% [markdown]
# To ensure that the data has been properly downloaded, we will preview the datasets. In addition, we will look at the distribution of the target values.

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68130 entries, 0 to 68129
# Data columns (total 72 columns):
# female                    68130 non-null int64
# age                       68130 non-null int64
# num_procedures            68130 non-null int64
# number_diagnoses          68130 non-null int64
# max_glu_serum             68130 non-null int64
# a1cresult                 68130 non-null int64
# change                    68130 non-null int64
# diabetesmed               68130 non-null int64
# icd_1                     68130 non-null int64
# icd_2                     68130 non-null int64
# icd_3                     68130 non-null int64
# icd_4                     68130 non-null int64
# icd_5                     68130 non-null int64
# icd_6                     68130 non-null int64
# icd_7                     68130 non-null int64
# icd_8                     68130 non-null int64
# icd_9                     68130 non-null int64
# icd_10                    68130 non-null int64
# icd_11                    68130 non-null int64
# icd_12                    68130 non-null int64
# icd_13                    68130 non-null int64
# icd_14                    68130 non-null int64
# icd_16                    68130 non-null int64
# icd_17                    68130 non-null int64
# icd_18                    68130 non-null int64
# icd_19                    68130 non-null int64
# num_meds                  68130 non-null int64
# num_down                  68130 non-null int64
# num_up                    68130 non-null int64
# race_black                68130 non-null int64
# race_other                68130 non-null int64
# at_not_urgent             68130 non-null int64
# at_urgent                 68130 non-null int64
# dd_care                   68130 non-null int64
# dd_care_home              68130 non-null int64
# dd_care_lt                68130 non-null int64
# dd_home                   68130 non-null int64
# dd_other                  68130 non-null int64
# no_info                   68130 non-null int64
# as_referral               68130 non-null int64
# as_transfer_er            68130 non-null int64
# as_transfer_other         68130 non-null int64
# metformin_down            68130 non-null int64
# metformin_steady          68130 non-null int64
# metformin_up              68130 non-null int64
# repaglinide_down          68130 non-null int64
# repaglinide_steady        68130 non-null int64
# repaglinide_up            68130 non-null int64
# glimepiride_down          68130 non-null int64
# glimepiride_steady        68130 non-null int64
# glimepiride_up            68130 non-null int64
# glipizide_down            68130 non-null int64
# glipizide_steady          68130 non-null int64
# glipizide_up              68130 non-null int64
# glyburide_down            68130 non-null int64
# glyburide_steady          68130 non-null int64
# glyburide_up              68130 non-null int64
# pioglitazone_down         68130 non-null int64
# pioglitazone_steady       68130 non-null int64
# pioglitazone_up           68130 non-null int64
# rosiglitazone_down        68130 non-null int64
# rosiglitazone_steady      68130 non-null int64
# rosiglitazone_up          68130 non-null int64
# insulin_down              68130 non-null int64
# insulin_steady            68130 non-null int64
# insulin_up                68130 non-null int64
# outpatient_binned         68130 non-null int64
# emergency_binned          68130 non-null int64
# inpatient_binned          68130 non-null int64
# time_in_hospital_log      68130 non-null float64
# num_lab_procedures_log    68130 non-null float64
# num_medications_log       68130 non-null float64
# dtypes: float64(3), int64(69)
# memory usage: 37.4 MB

# %%
y.value_counts()
# Out:
# 0    40168
# 1    27962
# Name: readmitted, dtype: int64

# %% [markdown]
# We can see that the data is ready for usage. However, we can also see that the target value is imbalanced.

# %% [markdown]
# ## Models

# %% [markdown]
# ### Baseline model — Dummy Classifier

# %% [markdown]
# Prior to implementing our baseline model, we split the data into a 75% training set and a 25% test set in preparation for the initial model. Since the target is imbalanced, this function will also stratify the test data to ensure target value proportionality. This function will also standardize all the features along a [0:1] axis.

# %%
X_train, X_test, y_train, y_test = f.standardize_train_test_split(X, y)

# %% [markdown]
# Our baseline model is a dummy classifier that automatically classifies each patient as "not returning". This function will create this model, and construct a classification matrix. Since failing to determine a patient that will need additional care is more potentially destructive than falsely classifying a patient as needing care, we will be using the Recall score to judge model effectiveness. For comparison's sake, we will also include the accuracy and the F1 score.

# %%
f.dummy_regression(X_train, X_test, y_train, y_test)
# Out:
# Recall score:  0.0
# Test Accuracy score:  0.589561439558504
# Test F1 score:  0.0

# %% [markdown]
# We will use this dummy regression as our baseline.

# %% [markdown]
# ----

# %% [markdown]
# ### Model #1 ⁠— Logistic Regression
# We will now determine the performance of a logistic regression. The following function will perform a grid search to determine which parameters optimize recall. It will then create a logistic regression model using these parameters, and return the recall and F1 scores. Finally, we will graph the model's performance. Since the targets are imbalanced, we will use a precision-recall curve instead of an ROC curve. The curve will include a 'no-skill' line defined by the ratio of the 'return' class to the 'no return' class.

# %%
f.log_gridsearch(X_train, y_train, X_test, y_test)
# Out:
# Best Parameter Combination Found During Grid Search:
# {'C': 5, 'fit_intercept': False, 'penalty': 'l2', 'tol': 0.0002, 'warm_start': True}
# Recall score:  0.28322128450865397
# Test Accuracy score:  0.6207362179299007
# Test F1 score:  0.3800383877159309
# AUC: 0.544279155473385

# %% [markdown]
# We can see that this model shows a better recall score than the dummy classifier (in addition to improved accuracy and F1 scores). From this point on, we will compare model performance, including precision-recall curve area under curve (AUC), to the logistic regression model.

# %% [markdown]
# ### Model #2 ⁠— Random Forests

# %% [markdown]
# Next, we will build and test a random forests model with bootstrapping to prevent overfitting.

# %% [markdown]
# In order to prevent training/test leakage, we will create new training and test datasets for each of our models.

# %%
X_train, X_test, y_train, y_test = f.standardize_train_test_split(X, y, rs=43)

# %% [markdown]
# The next function will perform a grid search to determine the best parameters for the random forests models and create the model. It will then return the scores, confusion matrix, and precision-recall curve.

# %%
f.forests_gridsearch(X_train, y_train, X_test, y_test)
# Out:
# Best Parameter Combination Found During Grid Search:
# {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'warm_start': True}
# Recall score:  0.3779144614504363
# Test Accuracy score:  0.5980156167439676
# Test F1 score:  0.4355782705465337
# AUC: 0.5116439039021635

# %% [markdown]
# We can see that although the logistic regression model outperforms the random forests model in accuracy and in the precision-recall curve AUC, it provides an improved recall score (in addition to the improved F1 score). Based on this, the random forests model is (for our purposes) superior to the logistic regression model. Next, we will use boosting on both the logistic and random forests models.

# %% [markdown]
# ----

# %% [markdown]
# ### Model #3 ⁠— AdaBoost

# %% [markdown]
# We will now create an AdaBoost logistic regression in order to determine whether boosting improves upon our logistic regression. We will create a new train/test split, perform a grid-search to determine the optimal parameters, and create a model. We will then return the model's scores, confusion matrix, and precision-recall curve for the subsequent model.

# %%
X_train, X_test, y_train, y_test = f.standardize_train_test_split(X, y, rs=44)

# %%
f.adaboost_gridsearch(X_train, y_train, X_test, y_test)
# Out:
# Best Parameter Combination Found During Grid Search:
# {'learning_rate': 1.4, 'n_estimators': 50}
# Recall score:  0.2973823487340867
# Test Accuracy score:  0.6251981447777843
# Test F1 score:  0.39442231075697215
# AUC: 0.5483152368438259

# %% [markdown]
# Although this marks an improvement in each scoring metric over the logistic regression, it still provides a worse recall score (and F1 score) than the random forests model. Next we will use a gradient boosting classifier to try to improve upon the random forests model.

# %% [markdown]
# ### Model #4 ⁠— Gradient Boosting Classifier

# %% [markdown]
# We will now create an gradient boosting classifier in order to determine whether boosting improves upon our random forests model.. We will create a new train/test split, perform a grid-search to determine the optimal parameters, and create a model. We will then return the model's scores, confusion matrix, and precision-recall curve for the subsequent model.

# %%
X_train, X_test, y_train, y_test = f.standardize_train_test_split(X, y, rs=45)

# %%
f.gboost_gridsearch(x_train, y_train, x_test, y_test)

# %% [markdown]
# ----

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Based on these calculations, we can determine that the Adaboost model performs the best using the recall score as the primary grading metric. It also outperforms the other models using the accuracy, F1 score, and AUC of the precision-recall curve. However, while these metrics outperform the dummy logistical regression baseline, the recall scores are still relatively low, indicating that the features are less-than-sufficient to accurately predict whether a patient will be returning to the hospital.
#
# In addition, since the dataset cannot specify whether the non-returning patients do not return due to a lack of health problems, or whether they are not returning due to other problems (ex. sudden death, inability to pay, etc.), a non-returning status should not be mistaken for a lack of medical need.
